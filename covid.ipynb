# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
url = "https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv"
covid = pd.read_csv(url)
covid.head()
# Out:
#   iso_code location        date  total_cases  new_cases  total_deaths  \
# 0      ABW    Aruba  2020-03-13            2          2             0
# 1      ABW    Aruba  2020-03-20            4          2             0
# 2      ABW    Aruba  2020-03-24           12          8             0
# 3      ABW    Aruba  2020-03-25           17          5             0
# 4      ABW    Aruba  2020-03-26           19          2             0
#
#    new_deaths  total_cases_per_million  new_cases_per_million  \
# 0           0                   18.733                 18.733
# 1           0                   37.465                 18.733
# 2           0                  112.395                 74.930
# 3           0                  159.227                 46.831
# 4           0                  177.959                 18.733
#
#    total_deaths_per_million  ...  aged_65_older  aged_70_older  \
# 0                       0.0  ...         13.085          7.452
# 1                       0.0  ...         13.085          7.452
# 2                       0.0  ...         13.085          7.452
# 3                       0.0  ...         13.085          7.452
# 4                       0.0  ...         13.085          7.452
#
#    gdp_per_capita  extreme_poverty  cvd_death_rate  diabetes_prevalence  \
# 0       35973.781              NaN             NaN                11.62
# 1       35973.781              NaN             NaN                11.62
# 2       35973.781              NaN             NaN                11.62
# 3       35973.781              NaN             NaN                11.62
# 4       35973.781              NaN             NaN                11.62
#
#    female_smokers male_smokers  handwashing_facilities  hospital_beds_per_100k
# 0             NaN          NaN                     NaN                     NaN
# 1             NaN          NaN                     NaN                     NaN
# 2             NaN          NaN                     NaN                     NaN
# 3             NaN          NaN                     NaN                     NaN
# 4             NaN          NaN                     NaN                     NaN
#
# [5 rows x 32 columns]

# %%
covid.shape[1]
# Out:
# 32

# %%
covid.describe().T
# Out:
#                                    count          mean           std  \
# total_cases                      21606.0  2.124004e+04  2.167326e+05
# new_cases                        21606.0  5.876979e+02  5.213689e+03
# total_deaths                     21606.0  1.385663e+03  1.433881e+04
# new_deaths                       21606.0  3.525039e+01  3.314962e+02
# total_cases_per_million          21221.0  5.794446e+02  1.616994e+03
# new_cases_per_million            21221.0  1.386974e+01  6.371891e+01
# total_deaths_per_million         21221.0  2.516461e+01  9.899253e+01
# new_deaths_per_million           21221.0  5.604963e-01  3.451747e+00
# total_tests                       5760.0  3.003000e+05  1.105118e+06
# new_tests                         5151.0  1.121015e+04  3.764051e+04
# total_tests_per_thousand          5760.0  1.304378e+01  2.350729e+01
# new_tests_per_thousand            5151.0  4.062658e-01  6.164956e-01
# new_tests_smoothed                6317.0  9.950049e+03  3.223014e+04
# new_tests_smoothed_per_thousand   6317.0  3.724972e-01  5.362105e-01
# stringency_index                 17047.0  5.636793e+01  3.365920e+01
# population                       21542.0  1.057521e+08  6.790961e+08
# population_density               20636.0  4.210586e+02  1.826755e+03
# median_age                       19623.0  3.226337e+01  8.972625e+00
# aged_65_older                    19356.0  9.819503e+00  6.458450e+00
# aged_70_older                    19524.0  6.249662e+00  4.433764e+00
# gdp_per_capita                   19344.0  2.297953e+04  2.129231e+04
# extreme_poverty                  12830.0  1.037472e+01  1.776547e+01
# cvd_death_rate                   19542.0  2.458280e+02  1.188779e+02
# diabetes_prevalence              20262.0  8.011737e+00  4.039355e+00
# female_smokers                   15856.0  1.127016e+01  1.056450e+01
# male_smokers                     15682.0  3.263855e+01  1.322821e+01
# handwashing_facilities            8595.0  5.500168e+01  3.102562e+01
# hospital_beds_per_100k           17989.0  3.217135e+00  2.602159e+00
#
#                                       min           25%           50%  \
# total_cases                         0.000  7.000000e+00  1.160000e+02
# new_cases                       -2461.000  0.000000e+00  2.000000e+00
# total_deaths                        0.000  0.000000e+00  2.000000e+00
# new_deaths                      -1918.000  0.000000e+00  0.000000e+00
# total_cases_per_million             0.000  1.070000e+00  4.096000e+01
# new_cases_per_million            -265.189  0.000000e+00  3.090000e-01
# total_deaths_per_million            0.000  0.000000e+00  3.150000e-01
# new_deaths_per_million            -41.023  0.000000e+00  0.000000e+00
# total_tests                         1.000  1.005625e+04  5.155250e+04
# new_tests                           1.000  6.060000e+02  2.081000e+03
# total_tests_per_thousand            0.000  4.477500e-01  2.958500e+00
# new_tests_per_thousand              0.000  3.400000e-02  1.620000e-01
# new_tests_smoothed                  0.000  7.080000e+02  2.257000e+03
# new_tests_smoothed_per_thousand     0.000  3.500000e-02  1.590000e-01
# stringency_index                    0.000  2.130000e+01  6.944000e+01
# population                        809.000  2.083380e+06  9.449321e+06
# population_density                  0.137  4.128500e+01  9.310500e+01
# median_age                         15.100  2.530000e+01  3.240000e+01
# aged_65_older                       1.144  3.941000e+00  7.724000e+00
# aged_70_older                       0.526  2.322000e+00  4.718000e+00
# gdp_per_capita                    661.240  6.426674e+03  1.566399e+04
# extreme_poverty                     0.100  5.000000e-01  1.600000e+00
# cvd_death_rate                     79.370  1.510890e+02  2.330700e+02
# diabetes_prevalence                 0.990  5.310000e+00  7.110000e+00
# female_smokers                      0.100  1.900000e+00  7.000000e+00
# male_smokers                        7.700  2.140000e+01  3.140000e+01
# handwashing_facilities              1.188  2.409700e+01  5.960700e+01
# hospital_beds_per_100k              0.100  1.400000e+00  2.600000e+00
#
#                                           75%           max
# total_cases                      1.498750e+03  6.348900e+06
# new_cases                        5.000000e+01  1.277960e+05
# total_deaths                     3.300000e+01  3.808100e+05
# new_deaths                       1.000000e+00  1.052000e+04
# total_cases_per_million          3.029160e+02  2.091557e+04
# new_cases_per_million            6.369000e+00  4.944376e+03
# total_deaths_per_million         5.925000e+00  1.237551e+03
# new_deaths_per_million           6.900000e-02  2.000400e+02
# total_tests                      1.859335e+05  1.693689e+07
# new_tests                        6.813500e+03  4.922760e+05
# total_tests_per_thousand         1.571175e+01  1.899180e+02
# new_tests_per_thousand           5.610000e-01  7.285000e+00
# new_tests_smoothed               6.225000e+03  3.998460e+05
# new_tests_smoothed_per_thousand  5.290000e-01  4.993000e+00
# stringency_index                 8.333000e+01  1.000000e+02
# population                       3.481387e+07  7.794799e+09
# population_density               2.273220e+02  1.934750e+04
# median_age                       4.080000e+01  4.820000e+01
# aged_65_older                    1.532200e+01  2.704900e+01
# aged_70_older                    9.829000e+00  1.849300e+01
# gdp_per_capita                   3.593837e+04  1.169356e+05
# extreme_poverty                  1.010000e+01  7.760000e+01
# cvd_death_rate                   3.111100e+02  7.244170e+02
# diabetes_prevalence              1.008000e+01  2.336000e+01
# female_smokers                   1.980000e+01  4.400000e+01
# male_smokers                     4.080000e+01  7.810000e+01
# handwashing_facilities           8.384100e+01  9.899900e+01
# hospital_beds_per_100k           4.280000e+00  1.380000e+01

# %%
covid.isna().sum() / len(covid) * 100
# Out:
# iso_code                            0.296214
# location                            0.000000
# date                                0.000000
# total_cases                         0.000000
# new_cases                           0.000000
# total_deaths                        0.000000
# new_deaths                          0.000000
# total_cases_per_million             1.781912
# new_cases_per_million               1.781912
# total_deaths_per_million            1.781912
# new_deaths_per_million              1.781912
# total_tests                        73.340739
# new_tests                          76.159400
# total_tests_per_thousand           73.340739
# new_tests_per_thousand             76.159400
# new_tests_smoothed                 70.762751
# new_tests_smoothed_per_thousand    70.762751
# tests_units                        67.995001
# stringency_index                   21.100620
# population                          0.296214
# population_density                  4.489494
# median_age                          9.178006
# aged_65_older                      10.413774
# aged_70_older                       9.636212
# gdp_per_capita                     10.469314
# extreme_poverty                    40.618347
# cvd_death_rate                      9.552902
# diabetes_prevalence                 6.220494
# female_smokers                     26.612978
# male_smokers                       27.418310
# handwashing_facilities             60.219384
# hospital_beds_per_100k             16.740720
# dtype: float64

# %%
covid.date = pd.to_datetime(covid.date, format="%Y-%m-%d")

# %%
covid.set_index('date', inplace=True)

# %%
covid.resample("D")["new_cases"].mean().plot(legend=False)
