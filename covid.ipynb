# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
url = "https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv"
covid = pd.read_csv(url,index_col='date',parse_dates=True)
covid.head()
# Out:
#            iso_code location  total_cases  new_cases  total_deaths  \
# date
# 2020-03-13      ABW    Aruba            2          2             0
# 2020-03-20      ABW    Aruba            4          2             0
# 2020-03-24      ABW    Aruba           12          8             0
# 2020-03-25      ABW    Aruba           17          5             0
# 2020-03-26      ABW    Aruba           19          2             0
#
#             new_deaths  total_cases_per_million  new_cases_per_million  \
# date
# 2020-03-13           0                   18.733                 18.733
# 2020-03-20           0                   37.465                 18.733
# 2020-03-24           0                  112.395                 74.930
# 2020-03-25           0                  159.227                 46.831
# 2020-03-26           0                  177.959                 18.733
#
#             total_deaths_per_million  new_deaths_per_million  ...  \
# date                                                          ...
# 2020-03-13                       0.0                     0.0  ...
# 2020-03-20                       0.0                     0.0  ...
# 2020-03-24                       0.0                     0.0  ...
# 2020-03-25                       0.0                     0.0  ...
# 2020-03-26                       0.0                     0.0  ...
#
#             aged_65_older  aged_70_older  gdp_per_capita  extreme_poverty  \
# date
# 2020-03-13         13.085          7.452       35973.781              NaN
# 2020-03-20         13.085          7.452       35973.781              NaN
# 2020-03-24         13.085          7.452       35973.781              NaN
# 2020-03-25         13.085          7.452       35973.781              NaN
# 2020-03-26         13.085          7.452       35973.781              NaN
#
#             cvd_death_rate  diabetes_prevalence female_smokers  male_smokers  \
# date
# 2020-03-13             NaN                11.62            NaN           NaN
# 2020-03-20             NaN                11.62            NaN           NaN
# 2020-03-24             NaN                11.62            NaN           NaN
# 2020-03-25             NaN                11.62            NaN           NaN
# 2020-03-26             NaN                11.62            NaN           NaN
#
#             handwashing_facilities  hospital_beds_per_100k
# date
# 2020-03-13                     NaN                     NaN
# 2020-03-20                     NaN                     NaN
# 2020-03-24                     NaN                     NaN
# 2020-03-25                     NaN                     NaN
# 2020-03-26                     NaN                     NaN
#
# [5 rows x 31 columns]

# %%
covid.shape[1]
# Out:
# 31

# %%
covid.describe().T
# Out:
#                                    count          mean           std  \
# total_cases                      21816.0  2.162923e+04  2.205111e+05
# new_cases                        21816.0  5.936601e+02  5.264744e+03
# total_deaths                     21816.0  1.407760e+03  1.453253e+04
# new_deaths                       21816.0  3.543674e+01  3.324378e+02
# total_cases_per_million          21431.0  5.877056e+02  1.634026e+03
# new_cases_per_million            21431.0  1.393892e+01  6.371496e+01
# total_deaths_per_million         21431.0  2.547801e+01  9.960581e+01
# new_deaths_per_million           21431.0  5.599982e-01  3.440356e+00
# total_tests                       5753.0  2.722256e+05  9.737837e+05
# new_tests                         5128.0  9.430434e+03  4.009790e+04
# total_tests_per_thousand          5753.0  1.393349e+01  2.468554e+01
# new_tests_per_thousand            5128.0  4.169323e-01  6.320506e-01
# new_tests_smoothed                6355.0  8.787654e+03  2.969175e+04
# new_tests_smoothed_per_thousand   6355.0  3.818747e-01  5.442953e-01
# stringency_index                 17109.0  5.640706e+01  3.362498e+01
# population                       21752.0  1.054458e+08  6.779952e+08
# population_density               20834.0  4.201704e+02  1.823980e+03
# median_age                       19809.0  3.224731e+01  8.974859e+00
# aged_65_older                    19539.0  9.810022e+00  6.456556e+00
# aged_70_older                    19709.0  6.242995e+00  4.432082e+00
# gdp_per_capita                   19526.0  2.294538e+04  2.128026e+04
# extreme_poverty                  12951.0  1.040803e+01  1.779539e+01
# cvd_death_rate                   19728.0  2.459244e+02  1.188542e+02
# diabetes_prevalence              20455.0  8.012232e+00  4.041239e+00
# female_smokers                   15997.0  1.126261e+01  1.056346e+01
# male_smokers                     15821.0  3.263853e+01  1.323162e+01
# handwashing_facilities            8687.0  5.495241e+01  3.103885e+01
# hospital_beds_per_100k           18154.0  3.215260e+00  2.600891e+00
#
#                                       min           25%          50%  \
# total_cases                         0.000  8.000000e+00      120.000
# new_cases                       -2461.000  0.000000e+00        2.000
# total_deaths                        0.000  0.000000e+00        2.000
# new_deaths                      -1918.000  0.000000e+00        0.000
# total_cases_per_million             0.000  1.130500e+00       42.372
# new_cases_per_million            -265.189  0.000000e+00        0.314
# total_deaths_per_million            0.000  0.000000e+00        0.334
# new_deaths_per_million            -41.023  0.000000e+00        0.000
# total_tests                         1.000  1.076800e+04    53005.000
# new_tests                           1.000  6.140000e+02     2027.000
# total_tests_per_thousand            0.000  4.980000e-01        3.158
# new_tests_per_thousand              0.000  3.600000e-02        0.167
# new_tests_smoothed                  0.000  7.280000e+02     2277.000
# new_tests_smoothed_per_thousand     0.000  3.700000e-02        0.165
# stringency_index                    0.000  2.222000e+01       69.440
# population                        809.000  2.083380e+06  9449321.000
# population_density                  0.137  4.128500e+01       93.105
# median_age                         15.100  2.520000e+01       32.200
# aged_65_older                       1.144  3.941000e+00        7.724
# aged_70_older                       0.526  2.322000e+00        4.718
# gdp_per_capita                    661.240  6.426674e+03    15663.986
# extreme_poverty                     0.100  5.000000e-01        1.600
# cvd_death_rate                     79.370  1.510890e+02      233.070
# diabetes_prevalence                 0.990  5.310000e+00        7.110
# female_smokers                      0.100  1.900000e+00        7.000
# male_smokers                        7.700  2.140000e+01       31.400
# handwashing_facilities              1.188  2.409700e+01       59.607
# hospital_beds_per_100k              0.100  1.400000e+00        2.600
#
#                                           75%           max
# total_cases                      1.526000e+03  6.475644e+06
# new_cases                        5.025000e+01  1.277960e+05
# total_deaths                     3.400000e+01  3.865440e+05
# new_deaths                       1.000000e+00  1.052000e+04
# total_cases_per_million          3.099330e+02  2.157539e+04
# new_cases_per_million            6.430000e+00  4.944376e+03
# total_deaths_per_million         6.094000e+00  1.237551e+03
# new_deaths_per_million           7.200000e-02  2.000400e+02
# total_tests                      1.898280e+05  1.890841e+07
# new_tests                        6.648000e+03  1.318362e+06
# total_tests_per_thousand         1.676400e+01  1.985050e+02
# new_tests_per_thousand           5.740000e-01  7.285000e+00
# new_tests_smoothed               6.101500e+03  5.320750e+05
# new_tests_smoothed_per_thousand  5.435000e-01  4.993000e+00
# stringency_index                 8.333000e+01  1.000000e+02
# population                       3.481387e+07  7.794799e+09
# population_density               2.273220e+02  1.934750e+04
# median_age                       4.080000e+01  4.820000e+01
# aged_65_older                    1.532200e+01  2.704900e+01
# aged_70_older                    9.829000e+00  1.849300e+01
# gdp_per_capita                   3.593837e+04  1.169356e+05
# extreme_poverty                  1.010000e+01  7.760000e+01
# cvd_death_rate                   3.178400e+02  7.244170e+02
# diabetes_prevalence              1.008000e+01  2.336000e+01
# female_smokers                   1.980000e+01  4.400000e+01
# male_smokers                     4.080000e+01  7.810000e+01
# handwashing_facilities           8.384100e+01  9.899900e+01
# hospital_beds_per_100k           4.280000e+00  1.380000e+01

# %%
covid.isna().sum() / len(covid) * 100
# Out:
# iso_code                            0.293363
# location                            0.000000
# total_cases                         0.000000
# new_cases                           0.000000
# total_deaths                        0.000000
# new_deaths                          0.000000
# total_cases_per_million             1.764760
# new_cases_per_million               1.764760
# total_deaths_per_million            1.764760
# new_deaths_per_million              1.764760
# total_tests                        73.629446
# new_tests                          76.494316
# total_tests_per_thousand           73.629446
# new_tests_per_thousand             76.494316
# new_tests_smoothed                 70.870004
# new_tests_smoothed_per_thousand    70.870004
# tests_units                        68.128896
# stringency_index                   21.575908
# population                          0.293363
# population_density                  4.501283
# median_age                          9.199670
# aged_65_older                      10.437294
# aged_70_older                       9.658049
# gdp_per_capita                     10.496883
# extreme_poverty                    40.635314
# cvd_death_rate                      9.570957
# diabetes_prevalence                 6.238541
# female_smokers                     26.673084
# male_smokers                       27.479831
# handwashing_facilities             60.180601
# hospital_beds_per_100k             16.785845
# dtype: float64

# %%
covid.resample("D")["new_cases"].mean().plot(legend=False)
